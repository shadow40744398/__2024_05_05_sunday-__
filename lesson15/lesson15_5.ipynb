# %%
import numpy as np
import pandas as pd
                            #範圍50~101間,選50位學生各5個成績
students = np.random.randint(50,101,size=(50,5))
stu = pd.DataFrame(students,
             columns=['國文','英文','數學','地理','歷史'], 
             index=[f'第{i}號' for i in range(1,51)]
             )#columns代表橫向,index代表縱向
stu
# Out:
#       國文   英文  數學   地理   歷史
# 第1號   63   77  55  100   87
# 第2號   70   56  95   75   90
# 第3號   58   89  65   51   87
# 第4號   97   57  76   91   70
# 第5號   90   69  81   82   96
# 第6號   72   56  97   86   77
# 第7號   64   79  77   50   97
# 第8號   54   62  68   64   69
# 第9號   58  100  84   54   83
# 第10號  66   79  51   80   86
# 第11號  51   68  97   95   85
# 第12號  68   70  81   56   86
# 第13號  91   65  93   94   84
# 第14號  80   57  93   91   70
# 第15號  90   69  76   62   64
# 第16號  94   95  71   77   88
# 第17號  91   93  73   75   87
# 第18號  59   97  82   70   56
# 第19號  64   73  82   69   65
# 第20號  51   58  50   56   85
# 第21號  91   71  68   62  100
# 第22號  85  100  87   62   68
# 第23號  91   56  77   78   80
# 第24號  76   61  86   67   68
# 第25號  71   76  52   88  100
# 第26號  92   93  82   54   76
# 第27號  53   70  92  100   71
# 第28號  68   60  92   58   72
# 第29號  61   79  81   59   98
# 第30號  70   83  97   54   96
# 第31號  62   53  80   98   65
# 第32號  87   66  89   53   52
# ...

# %%
stu.values

# %%
stu.to_numpy()

# %%
stu.to_numpy().tolist()
# Out:
# [[63, 77, 55, 100, 87],
#  [70, 56, 95, 75, 90],
#  [58, 89, 65, 51, 87],
#  [97, 57, 76, 91, 70],
#  [90, 69, 81, 82, 96],
#  [72, 56, 97, 86, 77],
#  [64, 79, 77, 50, 97],
#  [54, 62, 68, 64, 69],
#  [58, 100, 84, 54, 83],
#  [66, 79, 51, 80, 86],
#  [51, 68, 97, 95, 85],
#  [68, 70, 81, 56, 86],
#  [91, 65, 93, 94, 84],
#  [80, 57, 93, 91, 70],
#  [90, 69, 76, 62, 64],
#  [94, 95, 71, 77, 88],
#  [91, 93, 73, 75, 87],
#  [59, 97, 82, 70, 56],
#  [64, 73, 82, 69, 65],
#  [51, 58, 50, 56, 85],
#  [91, 71, 68, 62, 100],
#  [85, 100, 87, 62, 68],
#  [91, 56, 77, 78, 80],
#  [76, 61, 86, 67, 68],
#  [71, 76, 52, 88, 100],
#  [92, 93, 82, 54, 76],
#  [53, 70, 92, 100, 71],
#  [68, 60, 92, 58, 72],
#  [61, 79, 81, 59, 98],
#  [70, 83, 97, 54, 96],
#  [62, 53, 80, 98, 65],
#  [87, 66, 89, 53, 52],
#  [92, 62, 94, 85, 59],
#  [81, 55, 66, 94, 52],
#  [62, 77, 52, 68, 58],
#  [66, 69, 86, 94, 74],
#  [50, 85, 88, 83, 68],
#  [89, 67, 76, 51, 97],
#  [79, 61, 52, 95, 77],
# ...
